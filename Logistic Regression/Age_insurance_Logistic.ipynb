# %% [markdown]
# Predicting if a person would buy life insurnace based on his age using logistic regression
# Above is a binary logistic regression problem as there are only two possible outcomes (i.e. if person buys insurance or he/she doesn't)

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv("/content/insurance_data.csv")
df
# Out:
#     age  bought_insurance
# 0    22                 0
# 1    25                 0
# 2    47                 1
# 3    52                 0
# 4    46                 1
# 5    56                 1
# 6    55                 0
# 7    60                 1
# 8    62                 1
# 9    61                 1
# 10   18                 0
# 11   28                 0
# 12   27                 0
# 13   29                 0
# 14   49                 1
# 15   55                 1
# 16   25                 1
# 17   58                 1
# 18   19                 0
# 19   18                 0
# 20   21                 0
# 21   26                 0
# 22   40                 1
# 23   45                 1
# 24   50                 1
# 25   54                 1
# 26   23                 0

# %%
plt.scatter(df.age, df.bought_insurance, color="red",marker="+")
plt.xlabel('AGE')
plt.ylabel('Bought_insurance')
plt.show()

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test=train_test_split(df[['age']],df.bought_insurance,train_size=0.9)
X_test
# Out:
#     age
# 26   23
# 11   28
# 17   58

# %%
from sklearn.linear_model import LogisticRegression
model=LogisticRegression()

# %%
model.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
X_test
# Out:
#     age
# 26   23
# 11   28
# 17   58

# %%
y_predicted=model.predict(X_test)
y_predicted
# Out:
# array([0, 0, 1])

# %%
model.predict_proba(X_test)
# Out:
# array([[0.86884921, 0.13115079],
#        [0.78013868, 0.21986132],
#        [0.07730014, 0.92269986]])

# %%
model.score(X_test,y_test)
# Out:
# 1.0

# %%
y_predicted
# Out:
# array([0, 0, 1])

# %%
X_test
# Out:
#     age
# 26   23
# 11   28
# 17   58

# %%
#model.coef_ indicates value of m in y=m*x + b equation

model.coef_  #m
# Out:
# array([[0.12486943]])

# %%
model.intercept_ #b
# Out:
# array([-4.76281881])

# %%
0.12486943*35+-4.76281881
# Out:
# -0.39238875999999934

# %% [markdown]
# Defined sigmoid function

# %%
import math
def sigmoid(x):
  return 1/(1+math.exp(-x))

# %%
def prediction_function(age):
  z=0.125*age+-4.763
  y=sigmoid(z)
  return y

# %%
age=31
prediction_function(age)
# Out:
# 0.29152272959026204

# %% [markdown]
# # 0.291 is the less than 0.5 means the person with age 31 will not buy insurance.

# %%
age1=39
prediction_function(age1)
# Out:
# 0.5279707673355735

# %% [markdown]
# 0.527 is the less than 0.5 means the person with age 39 will not buy insurance.
